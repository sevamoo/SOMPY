# %%
import matplotlib.pylab as plt
# %matplotlib inline
# import sompy as sompy
import pandas as pd
import numpy as np
from time import time
import SOMPY as sompy

import sys

# %%
### A toy example: two dimensional data, four clusters

dlen = 200
Data1 = pd.DataFrame(data= 1*np.random.rand(dlen,2))
Data1.values[:,1] = (Data1.values[:,0][:,np.newaxis] + .42*np.random.rand(dlen,1))[:,0]


Data2 = pd.DataFrame(data= 1*np.random.rand(dlen,2)+1)
Data2.values[:,1] = (-1*Data2.values[:,0][:,np.newaxis] + .62*np.random.rand(dlen,1))[:,0]

Data3 = pd.DataFrame(data= 1*np.random.rand(dlen,2)+2)
Data3.values[:,1] = (.5*Data3.values[:,0][:,np.newaxis] + 1*np.random.rand(dlen,1))[:,0]


Data4 = pd.DataFrame(data= 1*np.random.rand(dlen,2)+3.5)
Data4.values[:,1] = (-.1*Data4.values[:,0][:,np.newaxis] + .5*np.random.rand(dlen,1))[:,0]


Data1 = np.concatenate((Data1,Data2,Data3,Data4))

fig = plt.figure()
plt.plot(Data1[:,0],Data1[:,1],'ob',alpha=0.2, markersize=4)
fig.set_size_inches(7,7)

# %%
mapsize = [20,20]
som = sompy.SOMFactory.build(Data1, mapsize, mask=None, mapshape='planar', lattice='rect', normalization='var', initialization='pca', neighborhood='gaussian', training='batch', name='sompy')  # this will use the default parameters, but i can change the initialization and neighborhood methods
som.train(n_job=1, verbose='debug')  # verbose='debug' will print more, and verbose=None wont print anything
# Out:
#  Training...
# --------------------------------------------------------------
#  details:
#       > data len is 800 and data dimension is 2
#       > map size is 20,20
#       > array size in log10 scale is 5.80617997398
#       > number of jobs in parallel: 1
#  --------------------------------------------------------------
#
#  pca_linear_initialization took: 0.048000 seconds
#  Rough training...
#  radius_ini: 3.000000 , radius_final: 1.000000, trainlen: 15
#
#  find_bmu took: 0.003000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 1 ---> elapsed time:  0.008000, quantization error: 0.232723
#
#  find_bmu took: 0.003000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 2 ---> elapsed time:  0.008000, quantization error: 0.115993
#
#  find_bmu took: 0.004000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 3 ---> elapsed time:  0.009000, quantization error: 0.078055
#
#  find_bmu took: 0.005000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 4 ---> elapsed time:  0.010000, quantization error: 0.075130
#
#  find_bmu took: 0.003000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 5 ---> elapsed time:  0.007000, quantization error: 0.068273
#
#  find_bmu took: 0.004000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 6 ---> elapsed time:  0.008000, quantization error: 0.063716
#
#  find_bmu took: 0.004000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 7 ---> elapsed time:  0.009000, quantization error: 0.059699
#
#  find_bmu took: 0.005000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 8 ---> elapsed time:  0.009000, quantization error: 0.055568
#
#  find_bmu took: 0.005000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 9 ---> elapsed time:  0.009000, quantization error: 0.052278
#
#  find_bmu took: 0.004000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 10 ---> elapsed time:  0.008000, quantization error: 0.048992
#
#  find_bmu took: 0.005000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 11 ---> elapsed time:  0.010000, quantization error: 0.045615
#
#  find_bmu took: 0.005000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 12 ---> elapsed time:  0.010000, quantization error: 0.042269
#
#  find_bmu took: 0.003000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 13 ---> elapsed time:  0.008000, quantization error: 0.039075
#
#  find_bmu took: 0.004000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 14 ---> elapsed time:  0.010000, quantization error: 0.036366
#
#  find_bmu took: 0.004000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 15 ---> elapsed time:  0.008000, quantization error: 0.033862
#
#  Finetune training...
#  radius_ini: 1.000000 , radius_final: 1.000000, trainlen: 20
#
#  find_bmu took: 0.005000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 1 ---> elapsed time:  0.009000, quantization error: 0.031547
#
#  find_bmu took: 0.003000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 2 ---> elapsed time:  0.006000, quantization error: 0.031177
#
#  find_bmu took: 0.004000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 3 ---> elapsed time:  0.008000, quantization error: 0.030862
#
#  find_bmu took: 0.004000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 4 ---> elapsed time:  0.008000, quantization error: 0.030710
#
#  find_bmu took: 0.003000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 5 ---> elapsed time:  0.007000, quantization error: 0.030594
#
#  find_bmu took: 0.004000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 6 ---> elapsed time:  0.008000, quantization error: 0.030639
#
#  find_bmu took: 0.005000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 7 ---> elapsed time:  0.009000, quantization error: 0.030639
#
#  find_bmu took: 0.003000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 8 ---> elapsed time:  0.006000, quantization error: 0.030644
#
#  find_bmu took: 0.003000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 9 ---> elapsed time:  0.006000, quantization error: 0.030561
#
#  find_bmu took: 0.003000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 10 ---> elapsed time:  0.007000, quantization error: 0.030576
#
#  find_bmu took: 0.004000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 11 ---> elapsed time:  0.008000, quantization error: 0.030565
#
#  find_bmu took: 0.005000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 12 ---> elapsed time:  0.009000, quantization error: 0.030596
#
#  find_bmu took: 0.004000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 13 ---> elapsed time:  0.008000, quantization error: 0.030544
#
#  find_bmu took: 0.004000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 14 ---> elapsed time:  0.008000, quantization error: 0.030565
#
#  find_bmu took: 0.004000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 15 ---> elapsed time:  0.007000, quantization error: 0.030581
#
#  find_bmu took: 0.004000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 16 ---> elapsed time:  0.007000, quantization error: 0.030584
#
#  find_bmu took: 0.003000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 17 ---> elapsed time:  0.006000, quantization error: 0.030633
#
#  find_bmu took: 0.003000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 18 ---> elapsed time:  0.006000, quantization error: 0.030633
#
#  find_bmu took: 0.004000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 19 ---> elapsed time:  0.008000, quantization error: 0.030633
#
#  find_bmu took: 0.004000 seconds
#  update_codebook_voronoi took: 0.001000 seconds
#  epoch: 20 ---> elapsed time:  0.008000, quantization error: 0.030633
#
#  --------------------------------------------------------------
#  Final quantization error: 0.030633
#  train took: 0.358000 seconds

# %%
v = sompy.mapview.View2DPacked(50, 50, 'test',text_size=8)  
# could be done in a one-liner: sompy.mapview.View2DPacked(300, 300, 'test').show(som)
v.show(som, what='codebook', which_dim=[0,1], CMAP=None, col_sz=6) #which_dim='all' default
# v.save('2d_packed_test')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-a4394db39fb6> in <module>()
# ----> 1 v = sompy.mapview.View2DPacked(50, 50, 'test',text_size=8)
#       2 # could be done in a one-liner: sompy.mapview.View2DPacked(300, 300, 'test').show(som)
#       3 v.show(som, what='codebook', which_dim=[0,1], CMAP=None, col_sz=6) #which_dim='all' default
#       4 # v.save('2d_packed_test')
#
# AttributeError: 'module' object has no attribute 'mapview'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-273a3a1301a9> in <module>()
# ----> 1 mapview
#
# NameError: name 'mapview' is not defined

# %%
mapview
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-273a3a1301a9> in <module>()
# ----> 1 mapview
#
# NameError: name 'mapview' is not defined
